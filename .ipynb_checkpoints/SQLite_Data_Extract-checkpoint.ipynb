# %%
# Importing dependencies for comunicating with sqlite db
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine,inspect, func, desc
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
import pyodbc
import sqlalchemy as sa
import urllib
import pandas as pd
import os

# %%
# Create engine to connect to Sensors.db
engine = create_engine('sqlite:///data/Sensors.db', echo=False)
Base = automap_base()

# %%
# Using Base.prepare and Base.classes we will reflect DB into ORM classes
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['BME_DATA']

# %%
# Explore database with inspector
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['BME_DATA']

# %%
# Save the refference from table BME_DATA
Rambo = Base.classes.BME_DATA

# %%
# Create db sesion object
session = Session(engine)

# %%
# Creating the query to identify last date to identify end ponint of the year
df = pd.read_sql("SELECT * FROM BME_DATA", engine)

# %%
df['TIME_STAMP'] = pd.to_datetime(df['TIME_STAMP'])

# %%
# using funciton to convert string into date time
from datetime import datetime, timedelta

def hour_rounder(t):
    # Rounds to nearest hour by adding a timedelta hour if minute >= 30
    return (t.replace(second=0, microsecond=0, minute=0, hour=t.hour)
               +timedelta(hours=t.minute//30))

# %%
# testing on  single value
test = hour_rounder(df['TIME_STAMP'][0])

# %%
# converting fro all values in entire column
df['TIME_STAMP'] = df['TIME_STAMP'].apply(hour_rounder)

# %%
# converting temperature from C to f
df['TEMPERATURE'] = round((df['TEMPERATURE']* 9/5) + 32)

# %%
# create new tale and drop Id
df = df[["TIME_STAMP", "TEMPERATURE"]]

# %%
df.head()
# Out:
#            TIME_STAMP  TEMPERATURE
# 0 2019-04-09 23:00:00        167.0
# 1 2019-04-09 23:00:00         68.0
# 2 2019-04-10 00:00:00         68.0
# 3 2019-04-10 01:00:00         67.0
# 4 2019-04-10 02:00:00         67.0

# %%
# Deleting the wrong input at the first row
df = df.iloc[1:]
df.head()
# Out:
#            TIME_STAMP  TEMPERATURE
# 1 2019-04-09 23:00:00         68.0
# 2 2019-04-10 00:00:00         68.0
# 3 2019-04-10 01:00:00         67.0
# 4 2019-04-10 02:00:00         67.0
# 5 2019-04-10 03:00:00         66.0

# %%
# Importing API data
#API_df = pd.read_csv("data/API.csv")
#API_df.head()

# %%
# Merging API and RAMBO dataframes On date
#master_df = pd.merge(fifa_subset, gdp_subset, on = "Nationality", how = "left", suffixes=("_",""))

# %%
# Export to csv
df.to_csv("Rambo.csv", sep=',', encoding='utf-8')
df.head()
# Out:
#            TIME_STAMP  TEMPERATURE
# 1 2019-04-09 23:00:00         68.0
# 2 2019-04-10 00:00:00         68.0
# 3 2019-04-10 01:00:00         67.0
# 4 2019-04-10 02:00:00         67.0
# 5 2019-04-10 03:00:00         66.0

# %%
# Importing API data
dfr = pd.read_csv("data/Rambo.csv")
dfr.head()
# Out:
#        TIME_STAMP  TEMPERATURE  F_Temp  A_Temp
# 0  4/11/2019 3:00           70   65.45   65.81
# 1  4/11/2019 4:00           68   62.79   64.10
# 2  4/11/2019 5:00           67   60.54   63.04
# 3  4/11/2019 6:00           67   60.48   62.80
# 4  4/11/2019 7:00           67   60.08   62.19

# %%
# Convert back to string for Json 
dfr['TIME_STAMP'] = dfr['TIME_STAMP'].dt.strftime('%m-%d-%Y %H:%M')
dfr.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-3a16d7a6bd65> in <module>
#       1 # Convert back to string for Json
# ----> 2 dfr['TIME_STAMP'] = dfr['TIME_STAMP'].dt.strftime('%m-%d-%Y %H:%M')
#       3 dfr.head()
#
# C:\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
#     135         # http://www.pydanny.com/cached-property.html
#
# C:\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     323             pass  # we raise an attribute error anyway
#     324
# --> 325         raise AttributeError("Can only use .dt accessor with datetimelike "
#     326                              "values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df_json_ready = dfr.to_json(orient='records')

# %%
df_json_ready
# Out:
# '[{"TIME_STAMP":"4\\/11\\/2019 3:00","TEMPERATURE":70,"F_Temp":65.45,"A_Temp":65.81},{"TIME_STAMP":"4\\/11\\/2019 4:00","TEMPERATURE":68,"F_Temp":62.79,"A_Temp":64.1},{"TIME_STAMP":"4\\/11\\/2019 5:00","TEMPERATURE":67,"F_Temp":60.54,"A_Temp":63.04},{"TIME_STAMP":"4\\/11\\/2019 6:00","TEMPERATURE":67,"F_Temp":60.48,"A_Temp":62.8},{"TIME_STAMP":"4\\/11\\/2019 7:00","TEMPERATURE":67,"F_Temp":60.08,"A_Temp":62.19},{"TIME_STAMP":"4\\/11\\/2019 8:00","TEMPERATURE":67,"F_Temp":60.08,"A_Temp":61.62},{"TIME_STAMP":"4\\/11\\/2019 9:00","TEMPERATURE":67,"F_Temp":60.88,"A_Temp":60.08},{"TIME_STAMP":"4\\/11\\/2019 10:00","TEMPERATURE":69,"F_Temp":60.65,"A_Temp":58.9},{"TIME_STAMP":"4\\/11\\/2019 11:00","TEMPERATURE":70,"F_Temp":60.1,"A_Temp":57.95},{"TIME_STAMP":"4\\/11\\/2019 12:00","TEMPERATURE":72,"F_Temp":60.14,"A_Temp":58.52},{"TIME_STAMP":"4\\/11\\/2019 13:00","TEMPERATURE":74,"F_Temp":63.5,"A_Temp":61.8},{"TIME_STAMP":"4\\/11\\/2019 14:00","TEMPERATURE":75,"F_Temp":67.9,"A_Temp":65.99},{"TIME_STAMP":"4\\/11\\/2019 15:00","TEMPERATURE":77,"F_Temp":71.61,"A_Temp":69.61},{"TIME_STAMP":"4\\/11\\/2019 16:00","TEMPERATURE":79,"F_Temp":74.56,"A_Temp":72.66},{"TIME_STAMP":"4\\/11\\/2019 17:00","TEMPERATURE":80,"F_Temp":77.36,"A_Temp":74.81},{"TIME_STAMP":"4\\/11\\/2019 18:00","TEMPERATURE":80,"F_Temp":79.4,"A_Temp":77.28},{"TIME_STAMP":"4\\/11\\/2019 19:00","TEMPERATURE":81,"F_Temp":80.87,"A_Temp":78.98},{"TIME_STAMP":"4\\/11\\/2019 20:00","TEMPERATURE":81,"F_Temp":81.14,"A_Temp":80.4},{"TIME_STAMP":"4\\/11\\/2019 21:00","TEMPERATURE":81,"F_Temp":81.6,"A_Temp":80.4},{"TIME_STAMP":"4\\/11\\/2019 22:00","TEMPERATURE":80,"F_Temp":81.11,"A_Temp":79.63},{"TIME_STAMP":"4\\/11\\/2019 23:00","TEMPERATURE":79,"F_Temp":79.93,"A_Temp":76